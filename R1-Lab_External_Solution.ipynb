# %% [markdown]
# # External Lab

# %% [markdown]
# # Part-1

# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
import pandas as pd
Iris=pd.read_csv('Iris.csv')
Iris.head()
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
Iris.dtypes
# Out:
# Sepal Length (in cm)    float64
# Sepal Width in (cm)     float64
# Petal length (in cm)    float64
# Petal width (in cm)     float64
# Class                    object
# dtype: object

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
#top 10 records
print(Iris.head(10))
#bottom 10 records
print(Iris.tail(10))
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa
# 5                  0.4  Iris-setosa
# 6                  0.3  Iris-setosa
# 7                  0.2  Iris-setosa
# 8                  0.2  Iris-setosa
# 9                  0.1  Iris-setosa
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# 143                  2.3  Iris-virginica
# 144                  2.5  Iris-virginica
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica

# %% [markdown]
# ### Find the shape of the dataset

# %%
Iris.shape
# Out:
# (150, 5)

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
Iris.set_index('Sepal Length (in cm)',inplace = False)
# Out:
#                       Sepal Width in (cm)  Petal length (in cm)  \
# Sepal Length (in cm)
# 5.1                                   3.5                   1.4
# 4.9                                   3.0                   1.4
# 4.7                                   3.2                   1.3
# 4.6                                   3.1                   1.5
# 5.0                                   3.6                   1.4
# 5.4                                   3.9                   1.7
# 4.6                                   3.4                   1.4
# 5.0                                   3.4                   1.5
# 4.4                                   2.9                   1.4
# 4.9                                   3.1                   1.5
# 5.4                                   3.7                   1.5
# 4.8                                   3.4                   1.6
# 4.8                                   3.0                   1.4
# 4.3                                   3.0                   1.1
# 5.8                                   4.0                   1.2
# 5.7                                   4.4                   1.5
# 5.4                                   3.9                   1.3
# 5.1                                   3.5                   1.4
# 5.7                                   3.8                   1.7
# 5.1                                   3.8                   1.5
# 5.4                                   3.4                   1.7
# 5.1                                   3.7                   1.5
# 4.6                                   3.6                   1.0
# 5.1                                   3.3                   1.7
# 4.8                                   3.4                   1.9
# 5.0                                   3.0                   1.6
# 5.0                                   3.4                   1.6
# 5.2                                   3.5                   1.5
# 5.2                                   3.4                   1.4
# 4.7                                   3.2                   1.6
# ...                                   ...                   ...
# 6.9                                   3.2                   5.7
# 5.6                                   2.8                   4.9
# 7.7                                   2.8                   6.7
# 6.3                                   2.7                   4.9
# 6.7                                   3.3                   5.7
# 7.2                                   3.2                   6.0
# 6.2                                   2.8                   4.8
# 6.1                                   3.0                   4.9
# 6.4                                   2.8                   5.6
# 7.2                                   3.0                   5.8
# 7.4                                   2.8                   6.1
# 7.9                                   3.8                   6.4
# 6.4                                   2.8                   5.6
# 6.3                                   2.8                   5.1
# 6.1                                   2.6                   5.6
# 7.7                                   3.0                   6.1
# 6.3                                   3.4                   5.6
# 6.4                                   3.1                   5.5
# 6.0                                   3.0                   4.8
# 6.9                                   3.1                   5.4
# 6.7                                   3.1                   5.6
# 6.9                                   3.1                   5.1
# 5.8                                   2.7                   5.1
# 6.8                                   3.2                   5.9
# 6.7                                   3.3                   5.7
# 6.7                                   3.0                   5.2
# 6.3                                   2.5                   5.0
# 6.5                                   3.0                   5.2
# 6.2                                   3.4                   5.4
# 5.9                                   3.0                   5.1
#
#                       Petal width (in cm)           Class
# Sepal Length (in cm)
# 5.1                                   0.2     Iris-setosa
# 4.9                                   0.2     Iris-setosa
# 4.7                                   0.2     Iris-setosa
# 4.6                                   0.2     Iris-setosa
# 5.0                                   0.2     Iris-setosa
# 5.4                                   0.4     Iris-setosa
# 4.6                                   0.3     Iris-setosa
# 5.0                                   0.2     Iris-setosa
# 4.4                                   0.2     Iris-setosa
# 4.9                                   0.1     Iris-setosa
# 5.4                                   0.2     Iris-setosa
# 4.8                                   0.2     Iris-setosa
# 4.8                                   0.1     Iris-setosa
# 4.3                                   0.1     Iris-setosa
# 5.8                                   0.2     Iris-setosa
# 5.7                                   0.4     Iris-setosa
# 5.4                                   0.4     Iris-setosa
# 5.1                                   0.3     Iris-setosa
# 5.7                                   0.3     Iris-setosa
# 5.1                                   0.3     Iris-setosa
# 5.4                                   0.2     Iris-setosa
# 5.1                                   0.4     Iris-setosa
# 4.6                                   0.2     Iris-setosa
# 5.1                                   0.5     Iris-setosa
# 4.8                                   0.2     Iris-setosa
# 5.0                                   0.2     Iris-setosa
# 5.0                                   0.4     Iris-setosa
# 5.2                                   0.2     Iris-setosa
# 5.2                                   0.2     Iris-setosa
# 4.7                                   0.2     Iris-setosa
# ...                                   ...             ...
# 6.9                                   2.3  Iris-virginica
# 5.6                                   2.0  Iris-virginica
# 7.7                                   2.0  Iris-virginica
# 6.3                                   1.8  Iris-virginica
# 6.7                                   2.1  Iris-virginica
# 7.2                                   1.8  Iris-virginica
# 6.2                                   1.8  Iris-virginica
# 6.1                                   1.8  Iris-virginica
# 6.4                                   2.1  Iris-virginica
# 7.2                                   1.6  Iris-virginica
# 7.4                                   1.9  Iris-virginica
# 7.9                                   2.0  Iris-virginica
# 6.4                                   2.2  Iris-virginica
# 6.3                                   1.5  Iris-virginica
# 6.1                                   1.4  Iris-virginica
# 7.7                                   2.3  Iris-virginica
# 6.3                                   2.4  Iris-virginica
# 6.4                                   1.8  Iris-virginica
# 6.0                                   1.8  Iris-virginica
# 6.9                                   2.1  Iris-virginica
# 6.7                                   2.4  Iris-virginica
# 6.9                                   2.3  Iris-virginica
# 5.8                                   1.9  Iris-virginica
# 6.8                                   2.3  Iris-virginica
# 6.7                                   2.5  Iris-virginica
# 6.7                                   2.3  Iris-virginica
# 6.3                                   1.9  Iris-virginica
# 6.5                                   2.0  Iris-virginica
# 6.2                                   2.3  Iris-virginica
# 5.9                                   1.8  Iris-virginica
#
# [150 rows x 4 columns]

# %% [markdown]
# ### Use iloc function to print all the rows of the 3rd column

# %%
Iris.iloc[:,2]
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
# 5      1.7
# 6      1.4
# 7      1.5
# 8      1.4
# 9      1.5
# 10     1.5
# 11     1.6
# 12     1.4
# 13     1.1
# 14     1.2
# 15     1.5
# 16     1.3
# 17     1.4
# 18     1.7
# 19     1.5
# 20     1.7
# 21     1.5
# 22     1.0
# 23     1.7
# 24     1.9
# 25     1.6
# 26     1.6
# 27     1.5
# 28     1.4
# 29     1.6
#       ...
# 120    5.7
# 121    4.9
# 122    6.7
# 123    4.9
# 124    5.7
# 125    6.0
# 126    4.8
# 127    4.9
# 128    5.6
# 129    5.8
# 130    6.1
# 131    6.4
# 132    5.6
# 133    5.1
# 134    5.6
# 135    6.1
# 136    5.6
# 137    5.5
# 138    4.8
# 139    5.4
# 140    5.6
# 141    5.1
# 142    5.1
# 143    5.9
# 144    5.7
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: Petal length (in cm), Length: 150, dtype: float64

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
Iris.loc[:9,['Sepal Width in (cm)','Sepal Length (in cm)']]
# Out:
#    Sepal Width in (cm)  Sepal Length (in cm)
# 0                  3.5                   5.1
# 1                  3.0                   4.9
# 2                  3.2                   4.7
# 3                  3.1                   4.6
# 4                  3.6                   5.0
# 5                  3.9                   5.4
# 6                  3.4                   4.6
# 7                  3.4                   5.0
# 8                  2.9                   4.4
# 9                  3.1                   4.9

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
Iris[Iris['Class'] == 'Iris-setosa']
# Out:
#     Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                    5.1                  3.5                   1.4
# 1                    4.9                  3.0                   1.4
# 2                    4.7                  3.2                   1.3
# 3                    4.6                  3.1                   1.5
# 4                    5.0                  3.6                   1.4
# 5                    5.4                  3.9                   1.7
# 6                    4.6                  3.4                   1.4
# 7                    5.0                  3.4                   1.5
# 8                    4.4                  2.9                   1.4
# 9                    4.9                  3.1                   1.5
# 10                   5.4                  3.7                   1.5
# 11                   4.8                  3.4                   1.6
# 12                   4.8                  3.0                   1.4
# 13                   4.3                  3.0                   1.1
# 14                   5.8                  4.0                   1.2
# 15                   5.7                  4.4                   1.5
# 16                   5.4                  3.9                   1.3
# 17                   5.1                  3.5                   1.4
# 18                   5.7                  3.8                   1.7
# 19                   5.1                  3.8                   1.5
# 20                   5.4                  3.4                   1.7
# 21                   5.1                  3.7                   1.5
# 22                   4.6                  3.6                   1.0
# 23                   5.1                  3.3                   1.7
# 24                   4.8                  3.4                   1.9
# 25                   5.0                  3.0                   1.6
# 26                   5.0                  3.4                   1.6
# 27                   5.2                  3.5                   1.5
# 28                   5.2                  3.4                   1.4
# 29                   4.7                  3.2                   1.6
# 30                   4.8                  3.1                   1.6
# 31                   5.4                  3.4                   1.5
# 32                   5.2                  4.1                   1.5
# 33                   5.5                  4.2                   1.4
# 34                   4.9                  3.1                   1.5
# 35                   5.0                  3.2                   1.2
# 36                   5.5                  3.5                   1.3
# 37                   4.9                  3.1                   1.5
# 38                   4.4                  3.0                   1.3
# 39                   5.1                  3.4                   1.5
# 40                   5.0                  3.5                   1.3
# 41                   4.5                  2.3                   1.3
# 42                   4.4                  3.2                   1.3
# 43                   5.0                  3.5                   1.6
# 44                   5.1                  3.8                   1.9
# 45                   4.8                  3.0                   1.4
# 46                   5.1                  3.8                   1.6
# 47                   4.6                  3.2                   1.4
# 48                   5.3                  3.7                   1.5
# 49                   5.0                  3.3                   1.4
#
#     Petal width (in cm)        Class
# 0                   0.2  Iris-setosa
# 1                   0.2  Iris-setosa
# 2                   0.2  Iris-setosa
# 3                   0.2  Iris-setosa
# 4                   0.2  Iris-setosa
# 5                   0.4  Iris-setosa
# 6                   0.3  Iris-setosa
# 7                   0.2  Iris-setosa
# 8                   0.2  Iris-setosa
# 9                   0.1  Iris-setosa
# 10                  0.2  Iris-setosa
# 11                  0.2  Iris-setosa
# 12                  0.1  Iris-setosa
# 13                  0.1  Iris-setosa
# 14                  0.2  Iris-setosa
# 15                  0.4  Iris-setosa
# 16                  0.4  Iris-setosa
# 17                  0.3  Iris-setosa
# 18                  0.3  Iris-setosa
# 19                  0.3  Iris-setosa
# 20                  0.2  Iris-setosa
# 21                  0.4  Iris-setosa
# 22                  0.2  Iris-setosa
# 23                  0.5  Iris-setosa
# 24                  0.2  Iris-setosa
# 25                  0.2  Iris-setosa
# 26                  0.4  Iris-setosa
# 27                  0.2  Iris-setosa
# 28                  0.2  Iris-setosa
# 29                  0.2  Iris-setosa
# 30                  0.2  Iris-setosa
# 31                  0.4  Iris-setosa
# 32                  0.1  Iris-setosa
# 33                  0.2  Iris-setosa
# 34                  0.1  Iris-setosa
# 35                  0.2  Iris-setosa
# 36                  0.2  Iris-setosa
# 37                  0.1  Iris-setosa
# 38                  0.2  Iris-setosa
# 39                  0.2  Iris-setosa
# 40                  0.3  Iris-setosa
# 41                  0.3  Iris-setosa
# 42                  0.2  Iris-setosa
# 43                  0.6  Iris-setosa
# 44                  0.4  Iris-setosa
# 45                  0.3  Iris-setosa
# 46                  0.2  Iris-setosa
# 47                  0.2  Iris-setosa
# 48                  0.2  Iris-setosa
# 49                  0.2  Iris-setosa

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
Iris['SepalExtra']=Iris['Sepal Length (in cm)']*Iris['Sepal Width in (cm)']
Iris.head()
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
#
#    Petal width (in cm)        Class  SepalExtra
# 0                  0.2  Iris-setosa       17.85
# 1                  0.2  Iris-setosa       14.70
# 2                  0.2  Iris-setosa       15.04
# 3                  0.2  Iris-setosa       14.26
# 4                  0.2  Iris-setosa       18.00

# %%
#print the value of Iris
Iris.head()
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
#
#    Petal width (in cm)        Class  SepalExtra
# 0                  0.2  Iris-setosa       17.85
# 1                  0.2  Iris-setosa       14.70
# 2                  0.2  Iris-setosa       15.04
# 3                  0.2  Iris-setosa       14.26
# 4                  0.2  Iris-setosa       18.00

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
print('Mean')
print(Iris.mean())
print('Variance')
print(Iris.var())
# Out:
# Mean
# Sepal Length (in cm)     5.843333
# Sepal Width in (cm)      3.054000
# Petal length (in cm)     3.758667
# Petal width (in cm)      1.198667
# SepalExtra              17.806533
# dtype: float64
# Variance
# Sepal Length (in cm)     0.685694
# Sepal Width in (cm)      0.188004
# Petal length (in cm)     3.113179
# Petal width (in cm)      0.582414
# SepalExtra              11.348090
# dtype: float64

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
def SepLenWid(length,width):
    print('length: {0}, Width : {1}'.format(length,width))
SepLenWid(Iris.loc[4,'Sepal Length (in cm)'],Iris.loc[4,'Sepal Width in (cm)'])
# Out:
# length: 5.0, Width : 3.6

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
#Way 1:using list comprehend
range=[Iris[i].max()- Iris[i].min() for i in list(Iris.columns) if i != 'Class']
print(range)
#way 2:storing in dataframe
df_iris_range =Iris.describe().loc[['max','min'],:].transpose()
df_iris_range['range']=df_iris_range['max']-df_iris_range['min']
df_iris_range
# Out:
# [3.6000000000000005, 2.4000000000000004, 5.9, 2.4, 20.02]
#                         max   min  range
# Sepal Length (in cm)   7.90   4.3   3.60
# Sepal Width in (cm)    4.40   2.0   2.40
# Petal length (in cm)   6.90   1.0   5.90
# Petal width (in cm)    2.50   0.1   2.40
# SepalExtra            30.02  10.0  20.02

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
Iris.sort_values(by=['Petal width (in cm)'],ascending = True)
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 32                    5.2                  4.1                   1.5
# 13                    4.3                  3.0                   1.1
# 37                    4.9                  3.1                   1.5
# 9                     4.9                  3.1                   1.5
# 12                    4.8                  3.0                   1.4
# 34                    4.9                  3.1                   1.5
# 0                     5.1                  3.5                   1.4
# 27                    5.2                  3.5                   1.5
# 28                    5.2                  3.4                   1.4
# 29                    4.7                  3.2                   1.6
# 30                    4.8                  3.1                   1.6
# 33                    5.5                  4.2                   1.4
# 36                    5.5                  3.5                   1.3
# 38                    4.4                  3.0                   1.3
# 39                    5.1                  3.4                   1.5
# 42                    4.4                  3.2                   1.3
# 46                    5.1                  3.8                   1.6
# 47                    4.6                  3.2                   1.4
# 48                    5.3                  3.7                   1.5
# 49                    5.0                  3.3                   1.4
# 25                    5.0                  3.0                   1.6
# 24                    4.8                  3.4                   1.9
# 35                    5.0                  3.2                   1.2
# 3                     4.6                  3.1                   1.5
# 2                     4.7                  3.2                   1.3
# 7                     5.0                  3.4                   1.5
# 8                     4.4                  2.9                   1.4
# 10                    5.4                  3.7                   1.5
# 4                     5.0                  3.6                   1.4
# 11                    4.8                  3.4                   1.6
# ..                    ...                  ...                   ...
# 111                   6.4                  2.7                   5.3
# 121                   5.6                  2.8                   4.9
# 122                   7.7                  2.8                   6.7
# 147                   6.5                  3.0                   5.2
# 113                   5.7                  2.5                   5.0
# 131                   7.9                  3.8                   6.4
# 110                   6.5                  3.2                   5.1
# 139                   6.9                  3.1                   5.4
# 102                   7.1                  3.0                   5.9
# 112                   6.8                  3.0                   5.5
# 105                   7.6                  3.0                   6.6
# 124                   6.7                  3.3                   5.7
# 128                   6.4                  2.8                   5.6
# 117                   7.7                  3.8                   6.7
# 132                   6.4                  2.8                   5.6
# 104                   6.5                  3.0                   5.8
# 120                   6.9                  3.2                   5.7
# 115                   6.4                  3.2                   5.3
# 148                   6.2                  3.4                   5.4
# 141                   6.9                  3.1                   5.1
# 143                   6.8                  3.2                   5.9
# 145                   6.7                  3.0                   5.2
# 118                   7.7                  2.6                   6.9
# 135                   7.7                  3.0                   6.1
# 136                   6.3                  3.4                   5.6
# 140                   6.7                  3.1                   5.6
# 114                   5.8                  2.8                   5.1
# 100                   6.3                  3.3                   6.0
# 144                   6.7                  3.3                   5.7
# 109                   7.2                  3.6                   6.1
#
#      Petal width (in cm)           Class  SepalExtra
# 32                   0.1     Iris-setosa       21.32
# 13                   0.1     Iris-setosa       12.90
# 37                   0.1     Iris-setosa       15.19
# 9                    0.1     Iris-setosa       15.19
# 12                   0.1     Iris-setosa       14.40
# 34                   0.1     Iris-setosa       15.19
# 0                    0.2     Iris-setosa       17.85
# 27                   0.2     Iris-setosa       18.20
# 28                   0.2     Iris-setosa       17.68
# 29                   0.2     Iris-setosa       15.04
# 30                   0.2     Iris-setosa       14.88
# 33                   0.2     Iris-setosa       23.10
# 36                   0.2     Iris-setosa       19.25
# 38                   0.2     Iris-setosa       13.20
# 39                   0.2     Iris-setosa       17.34
# 42                   0.2     Iris-setosa       14.08
# 46                   0.2     Iris-setosa       19.38
# 47                   0.2     Iris-setosa       14.72
# 48                   0.2     Iris-setosa       19.61
# 49                   0.2     Iris-setosa       16.50
# 25                   0.2     Iris-setosa       15.00
# 24                   0.2     Iris-setosa       16.32
# 35                   0.2     Iris-setosa       16.00
# 3                    0.2     Iris-setosa       14.26
# 2                    0.2     Iris-setosa       15.04
# 7                    0.2     Iris-setosa       17.00
# 8                    0.2     Iris-setosa       12.76
# 10                   0.2     Iris-setosa       19.98
# 4                    0.2     Iris-setosa       18.00
# 11                   0.2     Iris-setosa       16.32
# ..                   ...             ...         ...
# 111                  1.9  Iris-virginica       17.28
# 121                  2.0  Iris-virginica       15.68
# 122                  2.0  Iris-virginica       21.56
# 147                  2.0  Iris-virginica       19.50
# 113                  2.0  Iris-virginica       14.25
# 131                  2.0  Iris-virginica       30.02
# 110                  2.0  Iris-virginica       20.80
# 139                  2.1  Iris-virginica       21.39
# 102                  2.1  Iris-virginica       21.30
# 112                  2.1  Iris-virginica       20.40
# 105                  2.1  Iris-virginica       22.80
# 124                  2.1  Iris-virginica       22.11
# 128                  2.1  Iris-virginica       17.92
# 117                  2.2  Iris-virginica       29.26
# 132                  2.2  Iris-virginica       17.92
# 104                  2.2  Iris-virginica       19.50
# 120                  2.3  Iris-virginica       22.08
# 115                  2.3  Iris-virginica       20.48
# 148                  2.3  Iris-virginica       21.08
# 141                  2.3  Iris-virginica       21.39
# 143                  2.3  Iris-virginica       21.76
# 145                  2.3  Iris-virginica       20.10
# 118                  2.3  Iris-virginica       20.02
# 135                  2.3  Iris-virginica       23.10
# 136                  2.4  Iris-virginica       21.42
# 140                  2.4  Iris-virginica       20.77
# 114                  2.4  Iris-virginica       16.24
# 100                  2.5  Iris-virginica       20.79
# 144                  2.5  Iris-virginica       22.11
# 109                  2.5  Iris-virginica       25.92
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
Iris.drop(axis=1,columns='SepalExtra',inplace=True)
Iris.head()
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
IrisSubset=Iris.iloc[:10,:3]
print(IrisSubset)
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5

# %% [markdown]
# # Part-2

# %% [markdown]
# ## The dataset HR contains information collected from the survey floated by a HR within the company.
#
#
# As a part of this lab, you are expected to answer the below questions

# %% [markdown]
# ### Import numpy and Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters

# %%
df_hr=pd.read_csv('HR_external.txt',sep='\t')
df_hr.head()
# Out:
#   Individual  Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0        Ind1       Yes   41               1       1102           1
# 1        Ind2        No   49               2        279           2
# 2        Ind3       Yes   37               1       1373           2
# 3        Ind4        No   33               2       1392           2
# 4        Ind5        No   27               1        591           2
#
#    DistanceFromHome  Education  EducationField  EmployeeCount  ...  \
# 0                 1          2               1              1  ...
# 1                 8          1               1              1  ...
# 2                 2          2               6              1  ...
# 3                 3          4               1              1  ...
# 4                 2          1               2              1  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                         1             80                 0
# 1                         4             80                 1
# 2                         2             80                 0
# 3                         3             80                 0
# 4                         4             80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0                1               6
# 1                 10                      3                3              10
# 2                  7                      3                3               0
# 3                  8                      3                3               8
# 4                  6                      3                3               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                   4                        0                     5
# 1                   7                        1                     7
# 2                   0                        0                     0
# 3                   7                        3                     0
# 4                   2                        2                     2
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Print the no of rows and columns in the dataset

# %%
df_hr.shape
# Out:
# (1470, 35)

# %% [markdown]
# ### Find out the type of each and every column in the dataset

# %%
df_hr.dtypes
# Out:
# Individual                  object
# Attrition                   object
# Age                          int64
# BusinessTravel               int64
# DailyRate                    int64
# Department                   int64
# DistanceFromHome             int64
# Education                    int64
# EducationField               int64
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                       int64
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                      int64
# JobSatisfaction              int64
# MaritalStatus                int64
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                     int64
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %% [markdown]
# ### Print out all the rows from 3rd column to 10th columns

# %%
print(df_hr.iloc[:,2:10])
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      41               1       1102           1                 1          2
# 1      49               2        279           2                 8          1
# 2      37               1       1373           2                 2          2
# 3      33               2       1392           2                 3          4
# 4      27               1        591           2                 2          1
# 5      32               2       1005           2                 2          2
# 6      59               1       1324           2                 3          3
# 7      30               1       1358           2                24          1
# 8      38               2        216           2                23          3
# 9      36               1       1299           2                27          3
# 10     35               1        809           2                16          3
# 11     29               1        153           2                15          2
# 12     31               1        670           2                26          1
# 13     34               1       1346           2                19          2
# 14     28               1        103           2                24          3
# 15     29               1       1389           2                21          4
# 16     32               1        334           2                 5          2
# 17     22               3       1123           2                16          2
# 18     53               1       1219           1                 2          4
# 19     38               1        371           2                 2          3
# 20     24               3        673           2                11          2
# 21     36               1       1218           1                 9          4
# 22     34               1        419           2                 7          4
# 23     21               1        391           2                15          2
# 24     34               1        699           2                 6          1
# 25     53               1       1282           2                 5          3
# 26     32               2       1125           2                16          1
# 27     42               1        691           1                 8          4
# 28     44               1        477           2                 7          4
# 29     46               1        705           1                 2          4
# ...   ...             ...        ...         ...               ...        ...
# 1440   36               2        688           2                 4          2
# 1441   56               3        667           2                 1          4
# 1442   29               1       1092           2                 1          4
# 1443   42               1        300           2                 2          3
# 1444   56               1        310           2                 7          2
# 1445   41               1        582           2                28          4
# 1446   34               1        704           1                28          3
# 1447   36               3        301           1                15          4
# 1448   41               1        930           1                 3          3
# 1449   32               1        529           2                 2          3
# 1450   35               1       1146           3                26          4
# 1451   38               1        345           1                10          2
# 1452   50               2        878           1                 1          4
# 1453   36               1       1120           1                11          4
# 1454   45               1        374           1                20          3
# 1455   40               1       1322           2                 2          4
# 1456   35               2       1199           2                18          4
# 1457   40               1       1194           2                 2          4
# 1458   35               1        287           2                 1          4
# 1459   29               1       1378           2                13          2
# 1460   29               1        468           2                28          4
# 1461   50               1        410           1                28          3
# 1462   39               1        722           1                24          1
# 1463   31               3        325           2                 5          3
# 1464   26               1       1167           1                 5          3
# 1465   36               2        884           2                23          2
# 1466   39               1        613           2                 6          1
# 1467   27               1        155           2                 4          3
# 1468   49               2       1023           1                 2          3
# 1469   34               1        628           2                 8          3
#
#       EducationField  EmployeeCount
# 0                  1              1
# 1                  1              1
# 2                  6              1
# 3                  1              1
# 4                  2              1
# 5                  1              1
# 6                  2              1
# 7                  1              1
# 8                  1              1
# 9                  2              1
# 10                 2              1
# 11                 1              1
# 12                 1              1
# 13                 2              1
# 14                 1              1
# 15                 1              1
# 16                 1              1
# 17                 2              1
# 18                 1              1
# 19                 1              1
# 20                 6              1
# 21                 1              1
# 22                 1              1
# 23                 1              1
# 24                 2              1
# 25                 6              1
# 26                 1              1
# 27                 3              1
# 28                 2              1
# 29                 3              1
# ...              ...            ...
# 1440               1              1
# 1441               1              1
# 1442               2              1
# 1443               1              1
# 1444               4              1
# 1445               1              1
# 1446               3              1
# 1447               3              1
# 1448               1              1
# 1449               4              1
# 1450               1              1
# 1451               1              1
# 1452               1              1
# 1453               3              1
# 1454               1              1
# 1455               1              1
# 1456               1              1
# 1457               2              1
# 1458               1              1
# 1459               6              1
# 1460               2              1
# 1461               3              1
# 1462               3              1
# 1463               2              1
# 1464               6              1
# 1465               2              1
# 1466               2              1
# 1467               1              1
# 1468               2              1
# 1469               2              1
#
# [1470 rows x 8 columns]

# %% [markdown]
# ### Find out the no of male & female employees in the company
#
# *Hint: Use can use a condition to find out the no of 1s and 0s in gender and sum it*

# %%
#unique values in Gender
df_hr['Gender'].unique()
# Out:
# array([2, 1], dtype=int64)

# %%
#count of 1's 
df_hr[(df_hr['Gender']==1)]['Gender'].count()
# Out:
# 882

# %%
#count of 2's 
df_hr[(df_hr['Gender']==2)]['Gender'].count()
#another Way to get the value
#df_hr['Gender'].value_counts()
# Out:
# 588

# %% [markdown]
# ### Find out the IQR for the column - Age
#
# *Hint: IQR - Interquartile range = 75th percentile - 25th percentile*

# %%
df_hr['Age'].describe()['75%']-df_hr['Age'].describe()['25%']
# Out:
# 13.0

# %% [markdown]
# ### Find out the mean, median and variance for the column - DailyRate

# %%
print('Mean: ',df_hr['DailyRate'].mean())
print('Median: ',df_hr['DailyRate'].median())
print('Variance: ',df_hr['DailyRate'].var())
# Out:
# Mean:  802.4857142857143
# Median:  802.0
# Variance:  162819.59373723628

# %% [markdown]
# ### Plot the attrition column (Since it is a categorical variable, chose the plot accordingly)

# %%
import seaborn as sns
# %matplotlib inline
sns.countplot(x='Attrition',data=df_hr)

# %% [markdown]
# ### Plot Total working years using matplotlib plot function

# %%
import matplotlib.pyplot as plt
plt.hist(df_hr['TotalWorkingYears'],bins=None)
# Out:
# (array([165., 357., 437., 155., 119., 107.,  53.,  40.,  24.,  13.]),
#  array([ 0.,  4.,  8., 12., 16., 20., 24., 28., 32., 36., 40.]),
#  <a list of 10 Patch objects>)
